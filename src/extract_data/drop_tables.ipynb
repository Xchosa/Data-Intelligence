# %%
from config import config

tables = [
    config.bronze_table_aircrafts,
    config.bronze_table_airlines,
    config.bronze_table_countries,
    config.bronze_table_cities,
    config.bronze_table_airports
]

for table in tables:
    spark.sql(f"DROP TABLE IF EXISTS {table}")
